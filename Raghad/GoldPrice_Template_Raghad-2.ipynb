# %% [markdown]
# # Gold Price Prediction Project — Template

# %% [markdown]
# ## 1. Imports & Load Data

# %%
# write your code here
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import VotingClassifier
from sklearn.neural_network import MLPClassifier

import matplotlib.pyplot as plt

# %%
import kagglehub
import os

path = kagglehub.dataset_download("hayaalwizrah1/gold-price-prediction-dataset-20002026")
data = pd.read_csv(os.path.join(path, 'gold_data.csv'))
# Out:
# Downloading to /root/.cache/kagglehub/datasets/hayaalwizrah1/gold-price-prediction-dataset-20002026/1.archive...
# 100%|██████████| 941k/941k [00:00<00:00, 33.4MB/s]
# Extracting files...

# %%
df = pd.DataFrame(data=data)
df.head()
# Out:
#          Date   Gold_Open   Gold_High    Gold_Low  Gold_Close  Gold_Volume  \
# 0  2000-10-18  270.299988  270.299988  270.299988  270.299988          0.0
# 1  2000-10-19  270.100006  270.100006  270.100006  270.100006          1.0
# 2  2000-10-20  271.200012  271.200012  271.200012  271.200012         32.0
# 3  2000-10-23  271.700012  271.700012  270.100006  270.100006          1.0
# 4  2000-10-24  269.799988  270.100006  269.799988  270.100006         16.0
#
#           DXY        SP500        Oil        VIX  ...  Daily_Return  \
# 0  117.330002  1342.130005  33.549999  28.719999  ...     -0.002951
# 1  116.940002  1388.760010  32.950001  25.090000  ...     -0.000740
# 2  117.160004  1396.930054  34.299999  24.240000  ...      0.004073
# 3  117.540001  1395.780029  33.730000  24.690001  ...     -0.004056
# 4  117.419998  1398.130005  33.369999  24.280001  ...      0.000000
#
#          RSI      MACD  MACD_Signal  MACD_Hist    BB_Upper   BB_Middle  \
# 0  44.027677 -0.811933    -0.890278   0.078346  277.007532  272.364998
# 1  43.589968 -0.887787    -0.889780   0.001993  277.016104  272.354999
# 2  46.727258 -0.849350    -0.881694   0.032344  277.007681  272.325000
# 3  44.086729 -0.897306    -0.884817  -0.012490  276.828986  272.125000
# 4  44.086729 -0.924653    -0.892784  -0.031869  276.643831  271.935001
#
#      BB_Lower       ATR      Target
# 0  267.722464  1.797421  270.100006
# 1  267.693893  1.683319  271.200012
# 2  267.642319  1.641653  270.100006
# 3  267.421014  1.638679  270.100006
# 4  267.226170  1.543060  266.200012
#
# [5 rows x 25 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date', ascending=True)
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#         Date   Gold_Open   Gold_High    Gold_Low  Gold_Close  Gold_Volume  \
# 0 2000-10-18  270.299988  270.299988  270.299988  270.299988          0.0
# 1 2000-10-19  270.100006  270.100006  270.100006  270.100006          1.0
# 2 2000-10-20  271.200012  271.200012  271.200012  271.200012         32.0
# 3 2000-10-23  271.700012  271.700012  270.100006  270.100006          1.0
# 4 2000-10-24  269.799988  270.100006  269.799988  270.100006         16.0
#
#           DXY        SP500        Oil        VIX  ...  Daily_Return  \
# 0  117.330002  1342.130005  33.549999  28.719999  ...     -0.002951
# 1  116.940002  1388.760010  32.950001  25.090000  ...     -0.000740
# 2  117.160004  1396.930054  34.299999  24.240000  ...      0.004073
# 3  117.540001  1395.780029  33.730000  24.690001  ...     -0.004056
# 4  117.419998  1398.130005  33.369999  24.280001  ...      0.000000
#
#          RSI      MACD  MACD_Signal  MACD_Hist    BB_Upper   BB_Middle  \
# 0  44.027677 -0.811933    -0.890278   0.078346  277.007532  272.364998
# 1  43.589968 -0.887787    -0.889780   0.001993  277.016104  272.354999
# 2  46.727258 -0.849350    -0.881694   0.032344  277.007681  272.325000
# 3  44.086729 -0.897306    -0.884817  -0.012490  276.828986  272.125000
# 4  44.086729 -0.924653    -0.892784  -0.031869  276.643831  271.935001
#
#      BB_Lower       ATR      Target
# 0  267.722464  1.797421  270.100006
# 1  267.693893  1.683319  271.200012
# 2  267.642319  1.641653  270.100006
# 3  267.421014  1.638679  270.100006
# 4  267.226170  1.543060  266.200012
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 2. Quick Data Exploration (EDA)

# %%
# write your code here
df.shape
# Out:
# (6468, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          6468 non-null   datetime64[ns]
#  1   Gold_Open     6468 non-null   float64
#  2   Gold_High     6468 non-null   float64
#  3   Gold_Low      6468 non-null   float64
#  4   Gold_Close    6468 non-null   float64
#  5   Gold_Volume   6468 non-null   float64
#  6   DXY           6468 non-null   float64
#  7   SP500         6468 non-null   float64
#  8   Oil           6468 non-null   float64
#  9   VIX           6468 non-null   float64
#  10  Lag1          6468 non-null   float64
#  11  Lag7          6468 non-null   float64
#  12  MA7           6468 non-null   float64
#  13  MA30          6468 non-null   float64
#  14  EMA20         6468 non-null   float64
#  15  Daily_Return  6468 non-null   float64
#  16  RSI           6468 non-null   float64
#  17  MACD          6468 non-null   float64
#  18  MACD_Signal   6468 non-null   float64
#  19  MACD_Hist     6468 non-null   float64
#  20  BB_Upper      6468 non-null   float64
#  21  BB_Middle     6468 non-null   float64
#  22  BB_Lower      6468 non-null   float64
#  23  ATR           6468 non-null   float64
#  24  Target        6468 non-null   float64
# dtypes: datetime64[ns](1), float64(24)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#                                 Date    Gold_Open    Gold_High     Gold_Low  \
# count                           6468  6468.000000  6468.000000  6468.000000
# mean   2013-09-15 23:17:01.892393216  1331.326408  1338.590121  1323.732607
# min              2000-10-18 00:00:00   255.000000   256.100006   255.000000
# 25%              2007-04-17 18:00:00   662.500000   665.200012   660.724991
# 50%              2013-09-17 12:00:00  1258.549988  1265.600037  1253.450012
# 75%              2020-02-25 06:00:00  1719.375031  1728.325043  1708.950012
# max              2026-07-30 00:00:00  5415.700195  5586.200195  5301.600098
# std                              NaN   874.129231   880.732577   866.927261
#
#         Gold_Close    Gold_Volume          DXY        SP500          Oil  \
# count  6468.000000    6468.000000  6468.000000  6468.000000  6468.000000
# mean   1331.278663    4289.251237    92.508420  2405.750051    65.248230
# min     255.100006       0.000000    71.330002   676.530029   -37.630001
# 25%     662.500000      24.000000    82.599998  1209.544952    47.097499
# 50%    1258.400024     121.000000    93.235001  1693.320007    64.455002
# 75%    1719.925049     467.000000    99.512501  3087.815002    82.699997
# max    5318.399902  386334.000000   120.900002  7609.779785   145.289993
# std     873.866684   23983.824104    11.006872  1619.893786    24.513317
#
#                VIX  ...  Daily_Return          RSI         MACD  MACD_Signal  \
# count  6468.000000  ...   6468.000000  6468.000000  6468.000000  6468.000000
# mean     19.743652  ...      0.000484    52.922866     4.177401     4.209752
# min       9.140000  ...     -0.113662    16.555742  -152.862263  -115.158309
# 25%      13.970000  ...     -0.004845    44.500461    -4.174402    -3.937399
# 50%      17.585000  ...      0.000519    52.434576     1.816377     1.732898
# 75%      23.012500  ...      0.006401    61.602148    11.067144    10.772167
# max      82.690002  ...      0.090277    87.904154   227.374043   170.076845
# std       8.392199  ...      0.011262    12.197426    21.995293    20.787465
#
#          MACD_Hist     BB_Upper    BB_Middle     BB_Lower          ATR  \
# count  6468.000000  6468.000000  6468.000000  6468.000000  6468.000000
# mean     -0.032351  1374.027614  1325.715645  1277.403675    17.656730
# min     -95.153851   262.690584   259.269998   252.954794     0.858960
# 25%      -2.144649   684.193391   662.072501   639.583150     7.429916
# 50%       0.141395  1296.852761  1260.665005  1218.915205    14.667469
# 75%       2.370561  1777.566373  1719.417505  1662.596157    20.780509
# max      62.694653  5530.114159  5119.044971  4941.546783   200.652560
# std       6.302385   909.924973   867.760295   826.979542    18.848183
#
#             Target
# count  6468.000000
# mean   1331.862893
# min     255.100006
# 25%     662.574982
# 50%    1258.599976
# 75%    1720.325043
# max    5318.399902
# std     874.420246
#
# [8 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# Date            0
# Gold_Open       0
# Gold_High       0
# Gold_Low        0
# Gold_Close      0
# Gold_Volume     0
# DXY             0
# SP500           0
# Oil             0
# VIX             0
# Lag1            0
# Lag7            0
# MA7             0
# MA30            0
# EMA20           0
# Daily_Return    0
# RSI             0
# MACD            0
# MACD_Signal     0
# MACD_Hist       0
# BB_Upper        0
# BB_Middle       0
# BB_Lower        0
# ATR             0
# Target          0
# dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.plot(df['Date'], df['Gold_Close'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Close Over Time')
plt.show()

# %% [markdown]
# ## 3. Define Features and Target

# %%
# write your code here
y = df['Target']
X = df.drop(columns=["Date","Target", "Lag1","Gold_Close","Daily_Return"],axis=1)

# %%
df["pct_target"] = (df["Gold_Close"].shift(-1) - df["Gold_Close"]) / df["Gold_Close"]

# %%
y.shape, X.shape
# Out:
# ((6468,), (6468, 20))

# %% [markdown]
# ## 4. Chronological Split (Train / Validation / Test)

# %%
n = len(X)
train_end = int(n * 0.70)
val_end = int(n * 0.85)   # 0.70 + 0.15

# %%
X_train = X[:train_end]
X_val = X[train_end:val_end]
X_test = X[val_end:]

# %%
y_train = y[:train_end]
y_val = y[train_end:val_end]
y_test = y[val_end:]

# %%
print(X_train.shape[0] == y_train.shape[0])
print(X_val.shape[0] == y_val.shape[0])
print(X_test.shape[0] == y_test.shape[0])
# Out:
# True
# True
# True

# %%
X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# 6468

# %% [markdown]
# ## 5. Scaling

# %%
# write your code here
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled.mean(axis=0)
# Out:
# array([-5.02261267e-17, -1.00452253e-16,  0.00000000e+00,  0.00000000e+00,
#         3.51582887e-16, -1.00452253e-16,  2.51130633e-17, -1.25565317e-16,
#         1.50678380e-16,  2.51130633e-16, -3.01356760e-16, -5.02261267e-17,
#         1.63234912e-16, -1.25565317e-17,  1.25565317e-17,  5.88587422e-18,
#        -1.00452253e-16, -2.00904507e-16, -3.51582887e-16,  0.00000000e+00])

# %% [markdown]
# ## 6. Baseline

# %%
# write your code here
baseline_pred = df['Gold_Close'][val_end:]      # today's price, used as the naive guess for tomorrow
baseline_mae = mean_absolute_error(y_test, baseline_pred)

print(baseline_mae)
# Out:
# 27.46436628033278

# %%
 baseline_pred.shape[0] == y_test.shape[0]
# Out:
# True

# %%
import os, random
import numpy as np
import tensorflow as tf

seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## 7. Build & Compile & Train the Model (Dense Network)

# %%
# write your code here
def build_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='relu', input_shape=(20,)),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1)
    ])

    model.compile(
        optimizer="adam",
        loss="mae",
        metrics=["mae"]
    )
    return model

model = build_model()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
X_train_scaled.shape[1]
# Out:
# 20

# %%
# هنا جربت بدون early stop
#history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_data=(X_val_scaled, y_val))

# %% [markdown]
# ## 8. Early Stop

# %%
# write your code here

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

history = model.fit(
    X_train_scaled, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val_scaled, y_val),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 59.1423 - mae: 59.1423 - val_loss: 19.1478 - val_mae: 19.1478
# Epoch 2/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 58.8900 - mae: 58.8900 - val_loss: 18.9653 - val_mae: 18.9653
# Epoch 3/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 59.5163 - mae: 59.5163 - val_loss: 19.4113 - val_mae: 19.4113
# Epoch 4/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 58.4015 - mae: 58.4015 - val_loss: 25.4806 - val_mae: 25.4806
# Epoch 5/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 60.7327 - mae: 60.7327 - val_loss: 27.2614 - val_mae: 27.2614
# Epoch 6/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.2079 - mae: 59.2079 - val_loss: 31.7133 - val_mae: 31.7133
# Epoch 7/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.7358 - mae: 59.7358 - val_loss: 18.1947 - val_mae: 18.1947
# Epoch 8/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.4667 - mae: 58.4667 - val_loss: 22.6614 - val_mae: 22.6614
# Epoch 9/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.8134 - mae: 58.8134 - val_loss: 21.2294 - val_mae: 21.2294
# Epoch 10/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.2121 - mae: 59.2121 - val_loss: 28.9260 - val_mae: 28.9260
# Epoch 11/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.4609 - mae: 58.4609 - val_loss: 20.3399 - val_mae: 20.3399
# Epoch 12/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.9177 - mae: 58.9177 - val_loss: 28.8144 - val_mae: 28.8144
# Epoch 13/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.4602 - mae: 59.4602 - val_loss: 23.0155 - val_mae: 23.0155
# Epoch 14/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.5809 - mae: 57.5809 - val_loss: 17.5771 - val_mae: 17.5771
# Epoch 15/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.5152 - mae: 57.5152 - val_loss: 30.2379 - val_mae: 30.2379
# Epoch 16/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.6379 - mae: 58.6379 - val_loss: 21.5682 - val_mae: 21.5682
# Epoch 17/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.9746 - mae: 59.9746 - val_loss: 18.0145 - val_mae: 18.0145
# Epoch 18/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.2785 - mae: 59.2785 - val_loss: 20.4590 - val_mae: 20.4590
# Epoch 19/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.5474 - mae: 59.5474 - val_loss: 16.8996 - val_mae: 16.8996
# Epoch 20/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.9213 - mae: 58.9213 - val_loss: 16.6382 - val_mae: 16.6382
# Epoch 21/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 56.9443 - mae: 56.9443 - val_loss: 15.8466 - val_mae: 15.8466
# Epoch 22/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 58.0733 - mae: 58.0733 - val_loss: 19.2580 - val_mae: 19.2580
# Epoch 23/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 59.7340 - mae: 59.7340 - val_loss: 19.5085 - val_mae: 19.5085
# Epoch 24/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 58.7942 - mae: 58.7942 - val_loss: 32.7780 - val_mae: 32.7780
# Epoch 25/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.2016 - mae: 58.2016 - val_loss: 22.1681 - val_mae: 22.1681
# Epoch 26/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.2849 - mae: 59.2849 - val_loss: 27.7729 - val_mae: 27.7729
# Epoch 27/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.8813 - mae: 57.8813 - val_loss: 36.0785 - val_mae: 36.0785
# Epoch 28/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.7338 - mae: 57.7338 - val_loss: 26.0660 - val_mae: 26.0660
# Epoch 29/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 60.0144 - mae: 60.0144 - val_loss: 20.1667 - val_mae: 20.1667
# Epoch 30/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.2461 - mae: 59.2461 - val_loss: 17.1820 - val_mae: 17.1820
# Epoch 31/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 58.8482 - mae: 58.8482 - val_loss: 15.0878 - val_mae: 15.0878
# Epoch 32/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 60.0083 - mae: 60.0083 - val_loss: 52.0882 - val_mae: 52.0882
# Epoch 33/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 56.7138 - mae: 56.7138 - val_loss: 16.5419 - val_mae: 16.5419
# Epoch 34/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.7648 - mae: 57.7648 - val_loss: 19.3838 - val_mae: 19.3838
# Epoch 35/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.2733 - mae: 58.2733 - val_loss: 36.2253 - val_mae: 36.2253
# Epoch 36/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.7218 - mae: 57.7218 - val_loss: 15.6247 - val_mae: 15.6247
# Epoch 37/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 59.1940 - mae: 59.1940 - val_loss: 28.0088 - val_mae: 28.0088
# Epoch 38/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.6184 - mae: 58.6184 - val_loss: 27.0161 - val_mae: 27.0161
# Epoch 39/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 57.5337 - mae: 57.5337 - val_loss: 23.2818 - val_mae: 23.2818
# Epoch 40/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.5609 - mae: 58.5609 - val_loss: 18.6793 - val_mae: 18.6793
# Epoch 41/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 59.3636 - mae: 59.3636 - val_loss: 15.8959 - val_mae: 15.8959

# %% [markdown]
# ## 9. Evaluation

# %%
# write your code here
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MAE)')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test_scaled).flatten()

test_mae = mean_absolute_error(y_test, y_pred)
test_mse = mean_squared_error(y_test, y_pred)
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

test_r2 = r2_score(y_test, y_pred)

print("Test MAE:", test_mae)
print("Test MSE:", test_mse)
print("Test RMSE:", test_rmse)
print("Test R2:", test_r2)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test MAE: 34.9116134250692
# Test MSE: 3310.6680865192484
# Test RMSE: 57.53840531783314
# Test R2: 0.9966956102071854

# %%
print("Baseline MAE:", baseline_mae)
print("Model MAE:", test_mae)
print("Improvement:", (baseline_mae - test_mae) / baseline_mae * 100, "%")
# Out:
# Baseline MAE: 27.46436628033278
# Model MAE: 33.12842362597354
# Improvement: -20.623295246745922 %

# %%
print("y_train range:", y_train.min(), "-", y_train.max())
print("y_val range:", y_val.min(), "-", y_val.max())
print("y_test range:", y_test.min(), "-", y_test.max())
# عشان كذا ممكن طريقة التقسيمة هي اللي تحتاج تحسين
# Out:
# y_train range: 255.1000061035156 - 1888.699951171875
# y_val range: 1199.199951171875 - 2051.5
# y_test range: 1623.300048828125 - 5318.39990234375

# %%
z = df['pct_target']
z_train = z[:train_end]
z_val = z[train_end:val_end]
z_test = z[val_end:]

# %%
print("train:", z_train.min(), z_train.max())
print("val:", z_val.min(), z_val.max())
print("test:", z_test.min(), z_test.max())
# Out:
# train: -0.09353765783748334 0.09027685201022215
# val: -0.049787261049700764 0.05947667592334078
# test: -0.11366200569716554 0.06083292489183342

# %% [markdown]
# ## 10. Conclusion
# - Summarize your best result compared to the baseline
# - State the limitations (e.g. the price+indicators model doesn't account for sudden political events, data is daily only...)
